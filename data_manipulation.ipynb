# %%
import pandas as pd
df = pd.read_csv("C:/Users/liana/OneDrive/Desktop/Internship/Recommendation_Engine/etl/data/DEVICE_DIRECTORY.csv")
sdf = pd.read_csv("C:/Users/liana/OneDrive/Desktop/Internship/Recommendation_Engine/etl/data/SUB_DEVICE_DIRECTORY.csv")
df
# Out:
#          TAC            MODEL_NAME VENDOR_NAME             GSM_BANDS  \
# 0   35383304               Desire          HTC  1800; 1900; 850; 900
# 1   86093303                 A7010      Lenovo  1800; 1900; 850; 900
# 2   86735104                MI A2       Xiaomi  1800; 1900; 850; 900
# 3   35577310        105 2017 Dual        Nokia             1800; 900
# 4   86122904                    7      OnePlus  1800; 1900; 850; 900
# 5   35033005           Galaxy S22      Samsung  1800; 1900; 850; 900
# 6   86454005                  11T       Xiaomi  1800; 1900; 850; 900
# 7   35621458              Pixel 6   Google Inc                   NaN
# 8   86471606                11 5G      OnePlus  1800; 1900; 850; 900
# 9   35289210        105 2017 Dual        Nokia             1800; 900
# 10  35684067    iPhone 15 Pro Max        Apple  1800; 1900; 850; 900
# 11  35584505           Metro 2252      Samsung             1800; 900
# 12  35969104               One XL          HTC  1800; 1900; 850; 900
# ...

# %%
pd.set_option('display.max_columns', None)
df[["MODEL_NAME","VENDOR_NAME","RAM_SIZE"]]
df
# Out:
#          TAC            MODEL_NAME VENDOR_NAME             GSM_BANDS  \
# 0   35383304               Desire          HTC  1800; 1900; 850; 900
# 1   86093303                 A7010      Lenovo  1800; 1900; 850; 900
# 2   86735104                MI A2       Xiaomi  1800; 1900; 850; 900
# 3   35577310        105 2017 Dual        Nokia             1800; 900
# 4   86122904                    7      OnePlus  1800; 1900; 850; 900
# 5   35033005           Galaxy S22      Samsung  1800; 1900; 850; 900
# 6   86454005                  11T       Xiaomi  1800; 1900; 850; 900
# 7   35621458              Pixel 6   Google Inc                   NaN
# 8   86471606                11 5G      OnePlus  1800; 1900; 850; 900
# 9   35289210        105 2017 Dual        Nokia             1800; 900
# 10  35684067    iPhone 15 Pro Max        Apple  1800; 1900; 850; 900
# 11  35584505           Metro 2252      Samsung             1800; 900
# 12  35969104               One XL          HTC  1800; 1900; 850; 900
# ...

# %%
df.to_csv("C:/Users/liana/OneDrive/Desktop/Internship/Recommendation_Engine/etl/data/DEVICE_DIRECTORY.csv", index=False)  # Set index=False to exclude row numbers
sdf.to_csv("C:/Users/liana/OneDrive/Desktop/Internship/Recommendation_Engine/etl/data/SUB_DEVICE_DIRECTORY.csv",index=False)
pd.set_option('display.max_columns', None)

# %%
df[["MODEL_NAME","VENDOR_NAME","BATTERY_CAPACITY"]].sort_values("BATTERY_CAPACITY", ascending=False)
# Out:
#               MODEL_NAME VENDOR_NAME  BATTERY_CAPACITY
# 6                   11T       Xiaomi              5000
# 8                 11 5G      OnePlus              5000
# 7               Pixel 6   Google Inc              4614
# 10    iPhone 15 Pro Max        Apple              4422
# 4                     7      OnePlus              3700
# 5            Galaxy S22      Samsung              3700
# 1                  A7010      Lenovo              3300
# 13              Honor 6       Huawei              3100
# 2                 MI A2       Xiaomi              3000
# 16  Galaxy A5 2017 Dual      Samsung              3000
# 15                     5     OnePlus              3000
# 14  Galaxy A5 2017 Dual      Samsung              3000
# 12               One XL          HTC              1800
# 0                Desire          HTC              1400
# 11           Metro 2252      Samsung              1000
# 9         105 2017 Dual        Nokia               800
# ...
